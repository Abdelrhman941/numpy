# %%
import numpy as np          # type: ignore

# %% [markdown]
# <div style="background-color:rgb(85, 78, 79) ; color: #ffffff; width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# random - rand
# </div>

# %% [markdown]
# #### 👉 random and rand : numbers between 0,1

# %% [markdown]
# > ![image.png](attachment:image.png)

# %%
print(np.random.random())
print('----------')
##############################
a = np.random.random((2,3)) 
print(a)
print('----------')
print(a*10)
# Out:
# 0.2282051292073155
# ----------
# [[0.60512328 0.32578994 0.29233333]
#  [0.11749135 0.0085208  0.99374781]]
# ----------
# [[6.05123283 3.25789944 2.92333326]
#  [1.17491354 0.08520801 9.93747812]]

# %%
print(np.random.rand())
print('----------')
##############################
a = np.random.rand(15)
print(a)
print('----------')
print(a*10)
print('----------')
##############################
print(np.random.rand(3, 3))
# Out:
# 0.9688957235494196
# ----------
# [0.28622366 0.88172184 0.69635773 0.12051603 0.32851231 0.15308539
#  0.57924397 0.39168699 0.90552174 0.02887726 0.09724166 0.46950257
#  0.71934935 0.47935448 0.70978231]
# ----------
# [2.86223658 8.81721839 6.96357731 1.2051603  3.28512307 1.53085386
#  5.79243966 3.91686993 9.05521742 0.28877257 0.97241664 4.69502574
#  7.19349349 4.79354477 7.09782314]
# ----------
# [[0.38923425 0.80960541 0.86329259]
#  [0.70060691 0.42130582 0.32356198]
#  [0.84890913 0.26537296 0.29362414]]

# %% [markdown]
# <div style="background-color:rgb(85, 78, 79) ; color: #ffffff; width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# randint - uniform
# </div>

# %%
# randint : numbers int
a = np.random.randint(5) 
print(a)
print('----------')

a = np.random.randint(2,7) 
print(a) 
print('----------')

a = np.random.randint(1,10,20) 
print(a) 
print('----------')

a = np.random.randint(5,size=2) 
print(a)
print('----------')

a = np.random.randint(5,100,size=(2,4)) 
print(a)
# Out:
# 3
# ----------
# 3
# ----------
# [1 8 7 3 3 1 2 9 5 1 4 5 6 6 1 5 6 4 3 7]
# ----------
# [0 1]
# ----------
# [[ 9 20 90 36]
#  [22 51 21 50]]

# %%
# uniform : numbers float
a = np.random.uniform(5) 
print(a)
print('----------')

a = np.random.uniform(2,7) 
print(a) 
print('----------')

a = np.random.uniform(1,10,20) 
print(a) 
print('----------')

a = np.random.uniform(5,size=2) 
print(a)
print('----------')

a = np.random.uniform(5,100,size=(2,4)) 
print(a)
# Out:
# 4.060532827647631
# ----------
# 6.192966548663494
# ----------
# [8.91983149 2.04178109 7.40377038 1.68629543 2.36025512 6.625326
#  7.35077949 7.44850765 8.15546792 4.85159615 8.35554086 5.97209245
#  4.53299234 8.81941314 9.804918   8.16642236 7.01285378 2.34171604
#  2.74282671 6.21597134]
# ----------
# [1.09588825 4.44648386]
# ----------
# [[11.66275476 21.50237671 91.10378129  7.75400369]
#  [65.37013281 95.82327993 14.10578748 46.25819512]]

# %% [markdown]
# <div style="background-color:rgb(85, 78, 79) ; color: #ffffff; width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# normal
# </div>

# %%
a = np.random.normal(1,5,size=(2,4)) 
print(a)
# Out:
# [[ 5.19012811  7.8811762  -0.50568494 10.70524204]
#  [ 1.42580823  2.11558379 -0.41933907  2.25101828]]

# %% [markdown]
# <div style="background-color:rgb(85, 78, 79) ; color: #ffffff; width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# shuffle - permutation - choice
# </div>

# %% [markdown]
# #### 👉 shuffle : re-sort randomly

# %%
y = [1,2,3,6,9,8,5,4,7,8,9,6,5,9,6] 
a = np.random.shuffle(y) 
print(a) # None
print(y)
# Out:
# None
# [6, 1, 6, 9, 2, 9, 9, 8, 6, 3, 8, 5, 4, 7, 5]

# %% [markdown]
# #### 👉 permutation = shuffle

# %%
arr = np.array([1, 2, 3, 4, 5])
print(np.random.permutation(arr))
# Out:
# [1 2 4 3 5]

# %% [markdown]
# #### 👉 choice : choose randomly

# %%
y = [1,2,3,6,9,8,5,4,7,8,9,6,5,9,6] 
a = np.random.choice(y) 
b = np.random.choice(y,size = 5)
c = np.random.choice(y,(2,4)) 
print(a)
print('----------')
print(b)
print('----------')
print(c)
# Out:
# 5
# ----------
# [5 1 6 6 1]
# ----------
# [[8 8 5 9]
#  [2 6 5 1]]

# %% [markdown]
# <div style="background-color:rgb(85, 78, 79) ; color: #ffffff; width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# 😓 More
# </div>
#
# #### 👉 binomial - poisson - logistic - multinomial - exponential - chisquare

# %%
# n    -> number of trials.
# p    -> probability of occurrence of each trial (e.g. for toss of a coin 0.5 each).
# size -> The shape of the returned array.

x = np.random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [4 8 5 5 4 2 3 6 4 3]

# %%
# lam  -> rate or known number of occurrences e.g. 2 for above problem.
# size -> The shape of the returned array.

x = np.random.poisson(lam=2, size=10)
print(x)
# Out:
# [2 2 3 1 4 1 1 2 0 2]

# %%
# loc   -> mean, where the peak is. Default 0.
# scale -> standard deviation, the flatness of distribution. Default 1.
# size  -> The shape of the returned array.

x = np.random.logistic(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# [[ 3.16822952 10.25787347  1.91988672]
#  [ 3.30634005  2.25078916 -0.29070667]]

# %%
# n     -> number of possible outcomes (e.g. 6 for dice roll).
# pvals -> list of probabilities of outcomes (e.g. [1/6, 1/6, 1/6, 1/6, 1/6, 1/6] for dice roll).
# size  -> The shape of the returned array.

x = np.random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
print(x)
# Out:
# [0 1 1 1 2 1]

# %%
# scale -> inverse of rate ( see lam in poisson distribution ) defaults to 1.0.
# size  -> The shape of the returned array.

x = np.random.exponential(scale=2, size=(2, 3))
print(x)
# Out:
# [[1.17359372 0.61620272 2.19177974]
#  [0.48482944 1.32437995 4.14003449]]

# %%
# df   -> (degree of freedom).
# size -> The shape of the returned array.

x = np.random.chisquare(df=2, size=(2, 3))
print(x)
# Out:
# [[1.06764922 0.56012366 1.79748689]
#  [1.86148774 0.48892361 0.42267364]]

# %% [markdown]
# <div style="background-color:rgb(85, 78, 79) ; color: #ffffff; width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# random library
# </div>

# %%
import random as rn

# %% [markdown]
# > ### random is same in numpy but there is other function ``not exist in numpy.random`` like:
# #### 👉 `randrange(start"option", end, steps"option")` : **one** random integer from **0** to **n**

# %%
a = rn.randrange(150)
print(a)

b =rn.randrange(0,20,2)
print(b)
# Out:
# 109
# 10

# %% [markdown]
# #### 👉 `sample(range(), k)` : random **k** numbers from **range_start** to **range_end**

# %%
a =rn.sample(range(200) ,10)
print(a)
# Out:
# [128, 155, 87, 4, 11, 21, 84, 56, 114, 0]
